# %% [markdown]
# The $M$-sample Monte-Carlo estimate of the causal entropic force is
# $$
# \begin{align*}
#     f^{(c)}_j(\mathbf{x}_t, \tau)
#     &= - \frac{T_c}{T_r}
#     \int
#         f_{j,t} \,
#         p(\mathbf{x}_{t+\tau} \mid \mathbf{x}_t)
#         \ln p(\mathbf{x}_{t+\tau} \mid \mathbf{x}_t)
#     \,\mathrm{d} \mathbf{x}_{t+\tau}
# \\
#     &= - \frac{T_c}{T_r} \,
#     \mathbb{E}_{\mathbf{x}_{t+\tau} \sim p(\mathbf{x}_{t+\tau} \mid \mathbf{x}_t)} [
#         f_{j,t} \,
#         \ln p(\mathbf{x}_{t+\tau} \mid \mathbf{x}_t)
#     ]
# \\
#     &\approx - \frac{T_c}{T_r}
#     \frac{1}{M}
#     \sum_{i=1}^M
#         f_{j,t}^{(i)} \,
#         \ln p(\mathbf{x}_{t+\tau}^{(i)} \mid \mathbf{x}_t)
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
#     \Omega_i = \frac{1}{M \, p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t})}
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
#     f^{(c)}_j(\mathbf{x}_t, \tau)
# &\approx
#     - \frac{T_c}{T_r}
#     \left\langle
#         \sum_{i=1}^M
#             f_{j,t}^{(i)} \,
#             \Omega_i \,
#             \frac{1}{M \Omega_i}
#             \ln \frac{1}{M \Omega_i}
#     \right\rangle
# \\
# &=
#     - \frac{T_c}{T_r}
#     \left\langle
#         \sum_{i=1}^M
#             f_{j,t}^{(i)} \,
#             \frac{M \, \Omega_i}{M}
#             p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t})
#             \ln p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t})
#     \right\rangle
# \\
# &=
#     - \frac{T_c}{T_r}
#     \left\langle
#         \frac{1}{M}
#         \sum_{i=1}^M
#             f_{j,t}^{(i)} \,
#             \frac{1}{p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t})}
#             p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t})
#             \ln p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t})
#     \right\rangle
# \\
# &=
#     - \frac{T_c}{T_r}
#     \left\langle
#         \frac{1}{M}
#         \sum_{i=1}^M
#             f_{j,t}^{(i)} \,
#             \ln p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t})
#     \right\rangle
# \\
# &=
#     - \frac{T_c}{T_r} \,
#     \mathbb{E}_{p(\mathbf{x}_{t+\tau} \mid {\mathbf{x}_t})}
#     \left[
#         \frac{1}{M}
#         \sum_{i=1}^M
#             f_{j,t}^{(i)} \,
#             \ln p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t})
#     \right]
# \\
# &= - \frac{T_c}{T_r}
#     \int
#         p(\mathbf{x}_{t+\tau} \mid {\mathbf{x}_t})
#         \left(
#             \frac{1}{M}
#             \sum_{i=1}^M
#                 f_{j,t}^{(i)} \,
#                 \ln p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t})
#         \right)
#     \,\mathrm{d} \mathbf{x}_{t+\tau}
# \\
# &= - \frac{T_c}{T_r}
#     \int
#         p(\mathbf{x}_{t+\tau} \mid {\mathbf{x}_t})
#         \left(
#             \int
#                 \frac{1}{M}
#                 \sum_{i=1}^M
#                     f_{j,t}^{(i)} \,
#                     \delta \left(
#                         \mathbf{x}^{(i)}_{t+\tau} - \mathbf{x}
#                     \right)
#                 \ln p(\mathbf{x} \mid {\mathbf{x}_t})
#             \,\mathrm{d} \mathbf{x}
#         \right)
#     \,\mathrm{d} \mathbf{x}_{t+\tau}
# \\
# &\approx - \frac{T_c}{T_r}
#     \int
#         p(\mathbf{x}_{t+\tau} \mid {\mathbf{x}_t})
#         \left(
#             \int
#                 f_{j,t} \,
#                 p(\mathbf{x} \mid {\mathbf{x}_t})
#                 \ln p(\mathbf{x} \mid {\mathbf{x}_t})
#             \,\mathrm{d} \mathbf{x}
#         \right)
#     \,\mathrm{d} \mathbf{x}_{t+\tau}
# \\
# &\approx - \frac{T_c}{T_r}
#     \int
#         \frac{1}{M}
#         \sum_{i=1}^M
#             \delta \left(
#                 \mathbf{x}^{(i)}_{t+\tau} - \mathbf{x}
#             \right)
#         \left(
#             \int
#                 f_{j,t} \,
#                 p(\mathbf{x}_{t+\tau} \mid {\mathbf{x}_t})
#                 \ln p(\mathbf{x}_{t+\tau} \mid {\mathbf{x}_t})
#             \,\mathrm{d} \mathbf{x}_{t+\tau}
#         \right)
#     \,\mathrm{d} \mathbf{x}
# \\
# &= - \frac{T_c}{T_r}
#     \int
#         f_{j,t} \,
#         p(\mathbf{x}_{t+\tau} \mid {\mathbf{x}_t})
#         \ln p(\mathbf{x}_{t+\tau} \mid {\mathbf{x}_t})
#     \,\mathrm{d} \mathbf{x}_{t+\tau}
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# &= - \frac{T_c}{T_r}
#     \int
#         f_{j,t} \,
#         p(\mathbf{x}_{t+\tau} \mid {\mathbf{x}_t})
#         \ln p(\mathbf{x}_{t+\tau} \mid {\mathbf{x}_t})
#     \,\mathrm{d} \mathbf{x}_{t+\tau}
# \\
# &\approx - \frac{T_c}{T_r}
#     \int
#         \frac{1}{M}
#         \sum_{i=1}^M
#             \delta \left(
#                 \mathbf{x}^{(i)}_{t+\tau} - \mathbf{x}
#             \right)
#         \left(
#             \int
#                 f_{j,t} \,
#                 p(\mathbf{x}_{t+\tau} \mid {\mathbf{x}_t})
#                 \ln p(\mathbf{x}_{t+\tau} \mid {\mathbf{x}_t})
#             \,\mathrm{d} \mathbf{x}_{t+\tau}
#         \right)
#     \,\mathrm{d} \mathbf{x}
# \\
# &\approx - \frac{T_c}{T_r}
#     \int
#         \frac{1}{M}
#         \sum_{i=1}^M
#         \left(
#             \int
#                 f^{(i)}_{j,t} \,
#                 p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t})
#                 \ln p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t})
#             \,\mathrm{d} \mathbf{x}_{t+\tau}
#         \right)
#     \,\mathrm{d} \mathbf{x}
# \end{align*}
# $$

# %% [markdown]
# we construct
# $$
# \begin{align*}
#     p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t}) = \frac{1}{M \, \Omega_i}
# \end{align*}
# $$
# so
# $$
# \begin{align*}
#     \sum_{i=1}^M \frac{1}{M \, \Omega_i}
# \end{align*}
# $$

# %% [markdown]
# why, given $\Omega_i = \frac{1}{M \, p(\mathbf{x}^{(i)}_{t+\tau} \mid {\mathbf{x}_t})}$ does the following path integral approximate?
#
# $$
# \begin{align*}
#     \int
#         f_{j,t} \,
#         p(\mathbf{x}_{t+\tau} \mid \mathbf{x}_t)
#         \ln p(\mathbf{x}_{t+\tau} \mid \mathbf{x}_t)
#     \,\mathcal{D} ( \mathbf{x}_{t+\tau} )
# &\approx
#     \left\langle
#         \sum_{i=1}^M
#             f_{j,t} \,
#             \Omega_i \,
#             \frac{1}{M \Omega_i}
#             \ln \frac{1}{M \Omega_i}
#     \right\rangle
# \end{align*}
# $$
